# %% [markdown]
# # 마무리로 정리는 따로 진행하기 않겠습니다. GAN 실행으로 마무리 하겠습니다.

# %% [markdown]
# ---

# %% [markdown]
# ### **` 적대적 신경망 실행하기 `**

# %% [markdown]
# 생성자 : **`G()`**
# >
# 판별자 : **`D()`**
# >
# >
# <br>
#
#
# ### `진행형식`
# ---
# input(그림형태)
# <br>
# =>
# <br>
# 생성자 : `D(G(input))`
# <br>
# =>
# <br>
# 생성된 그림 : `G(input)`
# <br>
# =>
# <br>
# 판별자 : `진짜? : D(G(input))=0` or `가짜? : D(x)=1`
# ---

# %% [markdown]
# 만들어야하는 것 :
# <br>
# `D(G(input)` 과 실제 `D(x)` 를 판별자가 더는 구별못하게 `정확도 = 0.5` 에 가까워지면 생성자의 역할이 종료

# %% [markdown]
# `코드` : **현재 코드는 GAN 중 페이스북의 AI 연구팀이 만든 DCGAN 입니다**

# %% [markdown]
# # `코드` : 그룹나누기
# `[1]`
# ```python
# ginput= Input(shape=(100,))
# dis_output= discriminator(generator(ginput))
# gan = Model(ginput,dis_output)
# gan.compile(loss='binary_crossentropy', optimizer='adam')
# ```

# %% [markdown]
# **`[2]`**
# ```python
# def gan_train(epoch, batch_size, saving_interval):
#     (X_train, _), (_, _) = mnist.load_data()  # 들여쓰기 및 괄호 오류 수정
#     X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
#     X_train = (X_train - 127.5) / 127.5
#     true = np.ones((batch_size, 1))
#     fake = np.zeros((batch_size, 1))
#
#     for i in range(epoch):
#         idx = np.random.randint(0, X_train.shape[0], batch_size)
#         imgs = X_train[idx]
#         d_loss_real = discriminator.train_on_batch(imgs, true)
#
#         noise = np.random.normal(0, 1, (batch_size, 100))
#         gen_imgs = generator.predict(noise)
#         d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
#
#         d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)  # d_loss 계산 수정
#         g_loss = gan.train_on_batch(noise, true)
#
#         print('epoch:%d' % i, 'd_loss:%.4f' % d_loss, 'g_loss:%.4f' % g_loss)
#
#         if i % saving_interval == 0:
#             noise = np.random.normal(0, 1, (25, 100))
#             gen_imgs = generator.predict(noise)
#             gen_imgs = 0.5 * gen_imgs + 0.5
#
#             fig, axs = plt.subplots(5, 5)
#             count = 0
#             for j in range(5):
#                 for k in range(5):
#                     axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
#                     axs[j, k].axis('off')
#                     count += 1
#             fig.savefig("gan_images/gan_mnist_%d.png" % i)  # 들여쓰기 및 변수명 수정
#
# gan_train(4001, 32, 200)  # 함수 호출 위치 수정
# ```

# %% [markdown]
# ### -  `[GAN 해석] `

# %% [markdown]
# `[1]`
# ```python
# ginput= Input(shape=(100,))
# dis_output= discriminator(generator(ginput))
# gan = Model(ginput,dis_output)
# gan.compile(loss='binary_crossentropy', optimizer='adam')
# ```
# - 이 코드는 생성자와 판별자 모델을 연결시키는 gan 모델입니다.
# - input : keras.layers 의 함수로 인풋의 크기를 `shape`로 받습니다.
# - dis_output : D(G(input)) 을 수행하고 있습니다. - input 에 generator 모델을 쭉 돌리고 discriminator 모델을 쭉 돌린 것입니다.
# - gan : Model(ginput,dis_output) 은 keras.models 의 함수로 Model(a,b) 로 a 에는 input

# %% [markdown]
# `[2]`
# ```python
# def gan_train(epoch, batch_size, saving_interval):
# ```
#
#
#  ### `-` 신경망을 실행시키는 함수로 그 내부는 이렇게 작용합니다.
#
#  `MNIST 데이터 불러오기` <br>
#  `MNIST 의 이미지 활용`<br>
#  `실제 데이터 판별자에 입력`<br>
#  `가상 이미지를 판별자에 입력`<br>
#  `판별자와 생성자의 오차 계산`<br>
#  `gan_images 저장시키기.`<br>
#  `4000번마다 (batch_size=32) 200번마다 결과 저장`<br>

# %% [markdown]
# `-` GAN full model writing

# %% [markdown]
# 1. import
# 2. 생성자모델 만드기
# 3. 판별자모델만들기
# 4. 생성자와 판별자 모델 연결시키는 gan 모델 만들기
# 5. 신경망실행함수 만들기
# 6. 신경망실행함수 실행하여 결과보기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input,Dense, Reshape,Flatten,Dropout
from tensorflow.keras.layers import BatchNormalization,Activation, LeakyReLU, UpSampling2D,Conv2D
from tensorflow.keras.models import Sequential, Model
import numpy as np
import matplotlib.pyplot as plt

# %%
generator = Sequential()
generator.add(Dense(128*7*7 , input_dim=100 , activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7,7,128)))
generator.add(UpSampling2D()) # ...(1)
generator.add(Conv2D(64,kernel_size=5,padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D()) # ...(2)
generator.add(Conv2D(1, kernel_size=5,padding='same',activation='tanh'))

# %%
discriminator = Sequential()
discriminator.add(Conv2D(64,kernel_size=5,strides=2,input_shape=(28,28,1),padding='same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128,kernel_size=5,strides=2,padding='same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1,activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy',optimizer='adam')
discriminator.trainable=False

# %%
ginput= Input(shape=(100,)) #ginput 은 `g`an 의 `input` 을 의미
dis_output= discriminator(generator(ginput))
gan = Model(ginput,dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1078146 (4.11 MB)
# Trainable params: 852609 (3.25 MB)
# Non-trainable params: 225537 (881.00 KB)
# _________________________________________________________________

# %%
# 지금하고있는 폴더에 이미지 저장을 위해 gan_images 라는 폴더를 만들어놓으세요.

# %%
def gan_train(epoch, batch_size, saving_interval):
    (X_train, _), (_, _) = mnist.load_data()  # X_train 만 필요하고 나머지는 임의의 변수로 필요없다는 의미입니다.
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
    X_train = (X_train - 127.5) / 127.5 #60000,28,28,1 의 사진들에서 255의 절반인 127.5 를 빼주면서 -1과1사이로 정규화
    true = np.ones((batch_size, 1)) #32,1
    fake = np.zeros((batch_size, 1)) #32,1

    for i in range(epoch):
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]
        d_loss_real = discriminator.train_on_batch(imgs, true)

        noise = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(noise)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)  # d_loss 계산 수정
        g_loss = gan.train_on_batch(noise, true)

        print('epoch:%d' % i, 'd_loss:%.4f' % d_loss, 'g_loss:%.4f' % g_loss)

        if i % saving_interval == 0:
            noise = np.random.normal(0, 1, (25, 100))
            gen_imgs = generator.predict(noise)
            gen_imgs = 0.5 * gen_imgs + 0.5

            fig, axs = plt.subplots(5, 5)
            count = 0
            for j in range(5):
                for k in range(5):
                    axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                    axs[j, k].axis('off')
                    count += 1
            fig.savefig("gan_images/gan_mnist_%d.png" % i)  # 들여쓰기 및 변수명 수정

gan_train(4001, 32, 200)  # 함수 호출 위치 수정
# Out:
# 1/1 [==============================] - 0s 33ms/step
# epoch:0 d_loss:0.4201 g_loss:0.0707
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# epoch:1 d_loss:0.6238 g_loss:0.0202
# 1/1 [==============================] - 0s 32ms/step
# epoch:2 d_loss:0.7434 g_loss:0.0363
# 1/1 [==============================] - 0s 33ms/step
# epoch:3 d_loss:0.5985 g_loss:0.2081
# 1/1 [==============================] - 0s 31ms/step
# epoch:4 d_loss:0.4993 g_loss:0.6196
# 1/1 [==============================] - 0s 31ms/step
# epoch:5 d_loss:0.5383 g_loss:0.7894
# 1/1 [==============================] - 0s 32ms/step
# epoch:6 d_loss:0.5563 g_loss:0.7735
# 1/1 [==============================] - 0s 32ms/step
# epoch:7 d_loss:0.4962 g_loss:0.6669
# 1/1 [==============================] - 0s 32ms/step
# epoch:8 d_loss:0.4591 g_loss:0.6281
# 1/1 [==============================] - 0s 31ms/step
# epoch:9 d_loss:0.3943 g_loss:0.7066
# 1/1 [==============================] - 0s 31ms/step
# epoch:10 d_loss:0.3382 g_loss:0.9139
# 1/1 [==============================] - 0s 31ms/step
# epoch:11 d_loss:0.2731 g_loss:1.1595
# 1/1 [==============================] - 0s 32ms/step
# epoch:12 d_loss:0.2928 g_loss:1.4253
# 1/1 [==============================] - 0s 31ms/step
# epoch:13 d_loss:0.2402 g_loss:1.7894
# 1/1 [==============================] - 0s 32ms/step
# epoch:14 d_loss:0.3205 g_loss:1.5366
# 1/1 [==============================] - 0s 32ms/step
# epoch:15 d_loss:0.4098 g_loss:1.3574
# 1/1 [==============================] - 0s 31ms/step
# epoch:16 d_loss:0.5889 g_loss:1.0221
# 1/1 [==============================] - 0s 31ms/step
# epoch:17 d_loss:0.6128 g_loss:0.8665
# 1/1 [==============================] - 0s 31ms/step
# epoch:18 d_loss:0.5519 g_loss:1.1520
# 1/1 [==============================] - 0s 30ms/step
# epoch:19 d_loss:0.4763 g_loss:1.1752
# 1/1 [==============================] - 0s 31ms/step
# epoch:20 d_loss:0.8523 g_loss:0.8814
# 1/1 [==============================] - 0s 31ms/step
# epoch:21 d_loss:0.7114 g_loss:0.4905
# 1/1 [==============================] - 0s 31ms/step
# epoch:22 d_loss:0.6835 g_loss:0.4120
# 1/1 [==============================] - 0s 31ms/step
# epoch:23 d_loss:0.5398 g_loss:0.6272
# 1/1 [==============================] - 0s 32ms/step
# epoch:24 d_loss:0.4591 g_loss:0.8544
# 1/1 [==============================] - 0s 31ms/step
# epoch:25 d_loss:0.5317 g_loss:0.8600
# 1/1 [==============================] - 0s 32ms/step
# epoch:26 d_loss:0.5844 g_loss:0.7592
# 1/1 [==============================] - 0s 33ms/step
# epoch:27 d_loss:0.5578 g_loss:0.6482
# 1/1 [==============================] - 0s 36ms/step
# epoch:28 d_loss:0.5553 g_loss:0.6525
# 1/1 [==============================] - 0s 60ms/step
# epoch:29 d_loss:0.5041 g_loss:0.8067
# 1/1 [==============================] - 0s 60ms/step
# epoch:30 d_loss:0.4142 g_loss:0.9980
# 1/1 [==============================] - 0s 31ms/step
# epoch:31 d_loss:0.4358 g_loss:1.0495
# 1/1 [==============================] - 0s 49ms/step
# epoch:32 d_loss:0.5243 g_loss:0.8814
# 1/1 [==============================] - 0s 47ms/step
# epoch:33 d_loss:0.4157 g_loss:0.9312
# 1/1 [==============================] - 0s 47ms/step
# epoch:34 d_loss:0.4182 g_loss:1.0232
# 1/1 [==============================] - 0s 33ms/step
# epoch:35 d_loss:0.3824 g_loss:1.1579
# 1/1 [==============================] - 0s 42ms/step
# epoch:36 d_loss:0.3938 g_loss:1.2389
# 1/1 [==============================] - 0s 38ms/step
# epoch:37 d_loss:0.3436 g_loss:1.4314
# 1/1 [==============================] - 0s 31ms/step
# epoch:38 d_loss:0.3599 g_loss:1.4812
# 1/1 [==============================] - 0s 32ms/step
# epoch:39 d_loss:0.3358 g_loss:1.5634
# 1/1 [==============================] - 0s 34ms/step
# epoch:40 d_loss:0.3332 g_loss:1.8617
# 1/1 [==============================] - 0s 34ms/step
# epoch:41 d_loss:0.4015 g_loss:1.7087
# 1/1 [==============================] - 0s 32ms/step
# epoch:42 d_loss:0.2327 g_loss:2.4207
# 1/1 [==============================] - 0s 57ms/step
# epoch:43 d_loss:0.3573 g_loss:2.5492
# 1/1 [==============================] - 0s 36ms/step
# epoch:44 d_loss:0.2871 g_loss:2.8341
# 1/1 [==============================] - 0s 36ms/step
# epoch:45 d_loss:0.3108 g_loss:3.0737
# 1/1 [==============================] - 0s 38ms/step
# epoch:46 d_loss:0.3945 g_loss:3.0483
# 1/1 [==============================] - 0s 33ms/step
# epoch:47 d_loss:0.2228 g_loss:3.5325
# 1/1 [==============================] - 0s 65ms/step
# epoch:48 d_loss:0.2553 g_loss:3.7047
# 1/1 [==============================] - 0s 32ms/step
# epoch:49 d_loss:0.2764 g_loss:4.0823
# 1/1 [==============================] - 0s 32ms/step
# epoch:50 d_loss:0.2484 g_loss:3.9297
# 1/1 [==============================] - 0s 35ms/step
# epoch:51 d_loss:0.2082 g_loss:4.2980
# 1/1 [==============================] - 0s 32ms/step
# epoch:52 d_loss:0.1881 g_loss:4.4896
# 1/1 [==============================] - 0s 34ms/step
# epoch:53 d_loss:0.1799 g_loss:4.2704
# 1/1 [==============================] - 0s 36ms/step
# epoch:54 d_loss:0.3227 g_loss:3.9680
# 1/1 [==============================] - 0s 32ms/step
# epoch:55 d_loss:0.2853 g_loss:3.9993
# 1/1 [==============================] - 0s 33ms/step
# epoch:56 d_loss:0.2680 g_loss:3.8755
# 1/1 [==============================] - 0s 35ms/step
# epoch:57 d_loss:0.3394 g_loss:3.0060
# 1/1 [==============================] - 0s 36ms/step
# epoch:58 d_loss:0.3909 g_loss:2.2257
# 1/1 [==============================] - 0s 36ms/step
# epoch:59 d_loss:0.3073 g_loss:2.1750
# 1/1 [==============================] - 0s 32ms/step
# epoch:60 d_loss:0.1465 g_loss:2.5699
# 1/1 [==============================] - 0s 32ms/step
# epoch:61 d_loss:0.1454 g_loss:3.0720
# 1/1 [==============================] - 0s 33ms/step
# epoch:62 d_loss:0.1699 g_loss:2.3556
# 1/1 [==============================] - 0s 35ms/step
# epoch:63 d_loss:0.2079 g_loss:1.6514
# 1/1 [==============================] - 0s 33ms/step
# epoch:64 d_loss:0.1255 g_loss:2.4181
# 1/1 [==============================] - 0s 33ms/step
# epoch:65 d_loss:0.1643 g_loss:1.8197
# 1/1 [==============================] - 0s 33ms/step
# epoch:66 d_loss:0.2565 g_loss:2.7826
# 1/1 [==============================] - 0s 36ms/step
# epoch:67 d_loss:0.4589 g_loss:1.2382
# 1/1 [==============================] - 0s 35ms/step
# epoch:68 d_loss:0.6717 g_loss:1.2877
# 1/1 [==============================] - 0s 38ms/step
# epoch:69 d_loss:0.7683 g_loss:2.0423
# 1/1 [==============================] - 0s 34ms/step
# epoch:70 d_loss:0.7048 g_loss:1.7331
# 1/1 [==============================] - 0s 33ms/step
# epoch:71 d_loss:0.7772 g_loss:1.9594
# 1/1 [==============================] - 0s 33ms/step
# epoch:72 d_loss:0.6289 g_loss:2.4021
# 1/1 [==============================] - 0s 36ms/step
# epoch:73 d_loss:0.9855 g_loss:2.2817
# 1/1 [==============================] - 0s 33ms/step
# epoch:74 d_loss:0.6091 g_loss:2.3830
# 1/1 [==============================] - 0s 33ms/step
# epoch:75 d_loss:0.6025 g_loss:2.6741
# 1/1 [==============================] - 0s 33ms/step
# epoch:76 d_loss:0.4802 g_loss:2.7388
# 1/1 [==============================] - 0s 32ms/step
# epoch:77 d_loss:0.3399 g_loss:3.4507
# 1/1 [==============================] - 0s 32ms/step
# epoch:78 d_loss:0.4181 g_loss:3.0867
# 1/1 [==============================] - 0s 35ms/step
# epoch:79 d_loss:0.2562 g_loss:2.7523
# 1/1 [==============================] - 0s 32ms/step
# epoch:80 d_loss:0.5018 g_loss:1.9765
# 1/1 [==============================] - 0s 32ms/step
# epoch:81 d_loss:0.6964 g_loss:1.5869
# 1/1 [==============================] - 0s 32ms/step
# epoch:82 d_loss:0.6006 g_loss:1.4861
# 1/1 [==============================] - 0s 32ms/step
# epoch:83 d_loss:0.7357 g_loss:1.5821
# 1/1 [==============================] - 0s 33ms/step
# epoch:84 d_loss:0.6559 g_loss:1.7514
# 1/1 [==============================] - 0s 33ms/step
# epoch:85 d_loss:0.9766 g_loss:0.9500
# 1/1 [==============================] - 0s 32ms/step
# epoch:86 d_loss:1.1225 g_loss:0.6832
# 1/1 [==============================] - 0s 33ms/step
# epoch:87 d_loss:0.9567 g_loss:0.4794
# 1/1 [==============================] - 0s 31ms/step
# epoch:88 d_loss:0.6963 g_loss:0.7760
# 1/1 [==============================] - 0s 34ms/step
# epoch:89 d_loss:0.6736 g_loss:1.2198
# 1/1 [==============================] - 0s 33ms/step
# epoch:90 d_loss:0.5628 g_loss:1.5435
# 1/1 [==============================] - 0s 32ms/step
# epoch:91 d_loss:0.5864 g_loss:1.6145
# 1/1 [==============================] - 0s 32ms/step
# epoch:92 d_loss:0.3799 g_loss:2.0260
# 1/1 [==============================] - 0s 33ms/step
# epoch:93 d_loss:0.3046 g_loss:2.2147
# 1/1 [==============================] - 0s 33ms/step
# epoch:94 d_loss:0.2103 g_loss:2.7587
# 1/1 [==============================] - 0s 31ms/step
# epoch:95 d_loss:0.3393 g_loss:2.6373
# 1/1 [==============================] - 0s 33ms/step
# epoch:96 d_loss:0.2020 g_loss:3.1647
# 1/1 [==============================] - 0s 32ms/step
# epoch:97 d_loss:0.2519 g_loss:3.3258
# 1/1 [==============================] - 0s 32ms/step
# epoch:98 d_loss:0.3712 g_loss:2.9737
# 1/1 [==============================] - 0s 34ms/step
# epoch:99 d_loss:0.5703 g_loss:2.6923
# 1/1 [==============================] - 0s 38ms/step
# epoch:100 d_loss:0.6254 g_loss:2.9760
# 1/1 [==============================] - 0s 32ms/step
# epoch:101 d_loss:0.5569 g_loss:2.9347
# 1/1 [==============================] - 0s 33ms/step
# epoch:102 d_loss:0.8128 g_loss:2.9698
# 1/1 [==============================] - 0s 32ms/step
# epoch:103 d_loss:0.7475 g_loss:2.7577
# 1/1 [==============================] - 0s 33ms/step
# epoch:104 d_loss:0.6661 g_loss:2.5846
# 1/1 [==============================] - 0s 33ms/step
# epoch:105 d_loss:1.1290 g_loss:1.7399
# 1/1 [==============================] - 0s 34ms/step
# epoch:106 d_loss:0.8984 g_loss:1.4632
# 1/1 [==============================] - 0s 32ms/step
# epoch:107 d_loss:0.9172 g_loss:1.6091
# 1/1 [==============================] - 0s 33ms/step
# epoch:108 d_loss:0.7216 g_loss:1.4349
# 1/1 [==============================] - 0s 34ms/step
# epoch:109 d_loss:0.7936 g_loss:1.3448
# 1/1 [==============================] - 0s 33ms/step
# epoch:110 d_loss:0.7032 g_loss:1.1386
# 1/1 [==============================] - 0s 32ms/step
# epoch:111 d_loss:0.5984 g_loss:1.2890
# 1/1 [==============================] - 0s 33ms/step
# epoch:112 d_loss:0.5998 g_loss:1.2040
# 1/1 [==============================] - 0s 33ms/step
# epoch:113 d_loss:0.4065 g_loss:0.9612
# 1/1 [==============================] - 0s 33ms/step
# epoch:114 d_loss:0.4303 g_loss:1.1042
# 1/1 [==============================] - 0s 32ms/step
# epoch:115 d_loss:0.4067 g_loss:1.3209
# 1/1 [==============================] - 0s 33ms/step
# epoch:116 d_loss:0.3928 g_loss:1.3268
# 1/1 [==============================] - 0s 34ms/step
# epoch:117 d_loss:0.4025 g_loss:1.0752
# 1/1 [==============================] - 0s 33ms/step
# epoch:118 d_loss:0.4143 g_loss:1.0218
# 1/1 [==============================] - 0s 32ms/step
# epoch:119 d_loss:0.3602 g_loss:1.0165
# 1/1 [==============================] - 0s 33ms/step
# epoch:120 d_loss:0.4280 g_loss:1.0715
# 1/1 [==============================] - 0s 34ms/step
# epoch:121 d_loss:0.3164 g_loss:1.1008
# 1/1 [==============================] - 0s 32ms/step
# epoch:122 d_loss:0.4439 g_loss:1.1159
# 1/1 [==============================] - 0s 33ms/step
# epoch:123 d_loss:0.3575 g_loss:1.3199
# 1/1 [==============================] - 0s 33ms/step
# epoch:124 d_loss:0.5568 g_loss:1.0667
# 1/1 [==============================] - 0s 33ms/step
# epoch:125 d_loss:0.4206 g_loss:1.2500
# 1/1 [==============================] - 0s 33ms/step
# epoch:126 d_loss:0.4951 g_loss:1.0997
# 1/1 [==============================] - 0s 32ms/step
# epoch:127 d_loss:0.4145 g_loss:1.0653
# 1/1 [==============================] - 0s 33ms/step
# epoch:128 d_loss:0.5397 g_loss:1.0715
# 1/1 [==============================] - 0s 34ms/step
# epoch:129 d_loss:0.3904 g_loss:1.0746
# 1/1 [==============================] - 0s 33ms/step
# epoch:130 d_loss:0.4686 g_loss:1.2780
# 1/1 [==============================] - 0s 33ms/step
# epoch:131 d_loss:0.4470 g_loss:1.1463
# 1/1 [==============================] - 0s 34ms/step
# epoch:132 d_loss:0.3415 g_loss:1.1144
# 1/1 [==============================] - 0s 34ms/step
# epoch:133 d_loss:0.5010 g_loss:0.9943
# 1/1 [==============================] - 0s 31ms/step
# epoch:134 d_loss:0.5384 g_loss:0.9831
# 1/1 [==============================] - 0s 33ms/step
# epoch:135 d_loss:0.5571 g_loss:1.0014
# 1/1 [==============================] - 0s 33ms/step
# epoch:136 d_loss:0.6216 g_loss:0.8428
# 1/1 [==============================] - 0s 33ms/step
# epoch:137 d_loss:0.5344 g_loss:0.8698
# 1/1 [==============================] - 0s 32ms/step
# epoch:138 d_loss:0.6042 g_loss:0.9932
# 1/1 [==============================] - 0s 40ms/step
# epoch:139 d_loss:0.5615 g_loss:1.0776
# 1/1 [==============================] - 0s 37ms/step
# epoch:140 d_loss:0.6611 g_loss:1.3233
# 1/1 [==============================] - 0s 32ms/step
# epoch:141 d_loss:0.4822 g_loss:1.3536
# 1/1 [==============================] - 0s 35ms/step
# epoch:142 d_loss:0.5479 g_loss:1.3272
# 1/1 [==============================] - 0s 35ms/step
# epoch:143 d_loss:0.6167 g_loss:1.1414
# 1/1 [==============================] - 0s 37ms/step
# epoch:144 d_loss:0.5424 g_loss:1.2000
# 1/1 [==============================] - 0s 36ms/step
# epoch:145 d_loss:0.5634 g_loss:0.8659
# 1/1 [==============================] - 0s 34ms/step
# epoch:146 d_loss:0.4564 g_loss:1.1429
# 1/1 [==============================] - 0s 33ms/step
# epoch:147 d_loss:0.4978 g_loss:1.1260
# 1/1 [==============================] - 0s 35ms/step
# epoch:148 d_loss:0.4138 g_loss:1.3272
# 1/1 [==============================] - 0s 32ms/step
# epoch:149 d_loss:0.5274 g_loss:1.5001
# 1/1 [==============================] - 0s 32ms/step
# epoch:150 d_loss:0.4180 g_loss:1.6815
# 1/1 [==============================] - 0s 32ms/step
# epoch:151 d_loss:0.4692 g_loss:1.6858
# 1/1 [==============================] - 0s 31ms/step
# epoch:152 d_loss:0.4497 g_loss:1.6878
# 1/1 [==============================] - 0s 32ms/step
# epoch:153 d_loss:0.3683 g_loss:1.5715
# 1/1 [==============================] - 0s 33ms/step
# epoch:154 d_loss:0.3906 g_loss:1.6281
# 1/1 [==============================] - 0s 31ms/step
# epoch:155 d_loss:0.3733 g_loss:1.9299
# 1/1 [==============================] - 0s 34ms/step
# epoch:156 d_loss:0.4781 g_loss:1.6828
# 1/1 [==============================] - 0s 35ms/step
# epoch:157 d_loss:0.4438 g_loss:1.7499
# 1/1 [==============================] - 0s 33ms/step
# epoch:158 d_loss:0.5451 g_loss:1.6761
# 1/1 [==============================] - 0s 33ms/step
# epoch:159 d_loss:0.4235 g_loss:1.5148
# 1/1 [==============================] - 0s 34ms/step
# epoch:160 d_loss:0.4266 g_loss:1.6549
# 1/1 [==============================] - 0s 34ms/step
# epoch:161 d_loss:0.4718 g_loss:1.9275
# 1/1 [==============================] - 0s 32ms/step
# epoch:162 d_loss:0.5002 g_loss:1.6519
# 1/1 [==============================] - 0s 33ms/step
# epoch:163 d_loss:0.5809 g_loss:2.0003
# 1/1 [==============================] - 0s 32ms/step
# epoch:164 d_loss:0.4767 g_loss:1.5629
# 1/1 [==============================] - 0s 33ms/step
# epoch:165 d_loss:0.4583 g_loss:1.6859
# 1/1 [==============================] - 0s 32ms/step
# epoch:166 d_loss:0.4611 g_loss:1.5240
# 1/1 [==============================] - 0s 33ms/step
# epoch:167 d_loss:0.5994 g_loss:1.6717
# 1/1 [==============================] - 0s 31ms/step
# epoch:168 d_loss:0.4031 g_loss:1.8554
# 1/1 [==============================] - 0s 32ms/step
# epoch:169 d_loss:0.4578 g_loss:1.8264
# 1/1 [==============================] - 0s 32ms/step
# epoch:170 d_loss:0.5900 g_loss:1.6145
# 1/1 [==============================] - 0s 33ms/step
# epoch:171 d_loss:0.5242 g_loss:1.4773
# 1/1 [==============================] - 0s 31ms/step
# epoch:172 d_loss:0.4996 g_loss:1.3690
# 1/1 [==============================] - 0s 35ms/step
# epoch:173 d_loss:0.4749 g_loss:1.4404
# 1/1 [==============================] - 0s 34ms/step
# epoch:174 d_loss:0.5305 g_loss:1.2696
# 1/1 [==============================] - 0s 33ms/step
# epoch:175 d_loss:0.5751 g_loss:1.3400
# 1/1 [==============================] - 0s 33ms/step
# epoch:176 d_loss:0.5113 g_loss:1.5980
# 1/1 [==============================] - 0s 31ms/step
# epoch:177 d_loss:0.4181 g_loss:1.9188
# 1/1 [==============================] - 0s 34ms/step
# epoch:178 d_loss:0.5395 g_loss:1.6936
# 1/1 [==============================] - 0s 32ms/step
# epoch:179 d_loss:0.4375 g_loss:1.7755
# 1/1 [==============================] - 0s 32ms/step
# epoch:180 d_loss:0.4828 g_loss:1.4763
# 1/1 [==============================] - 0s 33ms/step
# epoch:181 d_loss:0.3748 g_loss:1.8315
# 1/1 [==============================] - 0s 32ms/step
# epoch:182 d_loss:0.3958 g_loss:1.4429
# 1/1 [==============================] - 0s 32ms/step
# epoch:183 d_loss:0.4856 g_loss:1.7285
# 1/1 [==============================] - 0s 33ms/step
# epoch:184 d_loss:0.4338 g_loss:1.8026
# 1/1 [==============================] - 0s 32ms/step
# epoch:185 d_loss:0.4160 g_loss:1.9214
# 1/1 [==============================] - 0s 34ms/step
# epoch:186 d_loss:0.4274 g_loss:1.6931
# 1/1 [==============================] - 0s 33ms/step
# epoch:187 d_loss:0.3501 g_loss:1.8940
# 1/1 [==============================] - 0s 33ms/step
# epoch:188 d_loss:0.3663 g_loss:1.7769
# 1/1 [==============================] - 0s 32ms/step
# epoch:189 d_loss:0.5370 g_loss:1.6535
# 1/1 [==============================] - 0s 33ms/step
# epoch:190 d_loss:0.3561 g_loss:1.9216
# 1/1 [==============================] - 0s 32ms/step
# epoch:191 d_loss:0.4018 g_loss:1.8451
# 1/1 [==============================] - 0s 36ms/step
# epoch:192 d_loss:0.4190 g_loss:1.7697
# 1/1 [==============================] - 0s 33ms/step
# epoch:193 d_loss:0.4165 g_loss:1.7114
# 1/1 [==============================] - 0s 33ms/step
# epoch:194 d_loss:0.4207 g_loss:1.4402
# 1/1 [==============================] - 0s 33ms/step
# epoch:195 d_loss:0.6471 g_loss:1.7218
# 1/1 [==============================] - 0s 33ms/step
# epoch:196 d_loss:0.5680 g_loss:1.8519
# 1/1 [==============================] - 0s 32ms/step
# epoch:197 d_loss:0.4459 g_loss:1.8088
# 1/1 [==============================] - 0s 33ms/step
# epoch:198 d_loss:0.4828 g_loss:1.8075
# 1/1 [==============================] - 0s 33ms/step
# epoch:199 d_loss:0.4886 g_loss:1.7433
# 1/1 [==============================] - 0s 33ms/step
# epoch:200 d_loss:0.4727 g_loss:1.6310
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# epoch:201 d_loss:0.4917 g_loss:1.6217
# 1/1 [==============================] - 0s 33ms/step
# epoch:202 d_loss:0.4129 g_loss:1.4987
# 1/1 [==============================] - 0s 32ms/step
# epoch:203 d_loss:0.5137 g_loss:1.6585
# 1/1 [==============================] - 0s 34ms/step
# epoch:204 d_loss:0.4946 g_loss:1.8569
# 1/1 [==============================] - 0s 33ms/step
# epoch:205 d_loss:0.5320 g_loss:1.7105
# 1/1 [==============================] - 0s 34ms/step
# epoch:206 d_loss:0.5377 g_loss:1.4052
# 1/1 [==============================] - 0s 33ms/step
# epoch:207 d_loss:0.5344 g_loss:1.5715
# 1/1 [==============================] - 0s 32ms/step
# epoch:208 d_loss:0.4497 g_loss:1.5869
# 1/1 [==============================] - 0s 35ms/step
# epoch:209 d_loss:0.4343 g_loss:1.6897
# 1/1 [==============================] - 0s 34ms/step
# epoch:210 d_loss:0.6053 g_loss:1.5812
# 1/1 [==============================] - 0s 32ms/step
# epoch:211 d_loss:0.4637 g_loss:1.4247
# 1/1 [==============================] - 0s 34ms/step
# epoch:212 d_loss:0.4295 g_loss:1.6318
# 1/1 [==============================] - 0s 34ms/step
# epoch:213 d_loss:0.4744 g_loss:1.3507
# 1/1 [==============================] - 0s 34ms/step
# epoch:214 d_loss:0.4889 g_loss:1.5705
# 1/1 [==============================] - 0s 37ms/step
# epoch:215 d_loss:0.4840 g_loss:1.5030
# 1/1 [==============================] - 0s 33ms/step
# epoch:216 d_loss:0.4398 g_loss:1.7864
# 1/1 [==============================] - 0s 35ms/step
# epoch:217 d_loss:0.4960 g_loss:1.5701
# 1/1 [==============================] - 0s 38ms/step
# epoch:218 d_loss:0.6153 g_loss:1.3991
# 1/1 [==============================] - 0s 35ms/step
# epoch:219 d_loss:0.5844 g_loss:1.3228
# 1/1 [==============================] - 0s 32ms/step
# epoch:220 d_loss:0.4954 g_loss:1.4830
# 1/1 [==============================] - 0s 33ms/step
# epoch:221 d_loss:0.4950 g_loss:1.4596
# 1/1 [==============================] - 0s 32ms/step
# epoch:222 d_loss:0.5498 g_loss:1.5812
# 1/1 [==============================] - 0s 32ms/step
# epoch:223 d_loss:0.6472 g_loss:1.3681
# 1/1 [==============================] - 0s 32ms/step
# epoch:224 d_loss:0.5741 g_loss:1.3697
# 1/1 [==============================] - 0s 32ms/step
# epoch:225 d_loss:0.5467 g_loss:1.4240
# 1/1 [==============================] - 0s 33ms/step
# epoch:226 d_loss:0.5636 g_loss:1.3719
# 1/1 [==============================] - 0s 32ms/step
# epoch:227 d_loss:0.5385 g_loss:1.3370
# 1/1 [==============================] - 0s 33ms/step
# epoch:228 d_loss:0.4580 g_loss:1.3824
# 1/1 [==============================] - 0s 33ms/step
# epoch:229 d_loss:0.6487 g_loss:1.5673
# 1/1 [==============================] - 0s 35ms/step
# epoch:230 d_loss:0.4871 g_loss:1.6834
# 1/1 [==============================] - 0s 32ms/step
# epoch:231 d_loss:0.5090 g_loss:1.7129
# 1/1 [==============================] - 0s 33ms/step
# epoch:232 d_loss:0.4866 g_loss:1.5904
# 1/1 [==============================] - 0s 33ms/step
# epoch:233 d_loss:0.5079 g_loss:1.6478
# 1/1 [==============================] - 0s 33ms/step
# epoch:234 d_loss:0.4922 g_loss:1.8507
# 1/1 [==============================] - 0s 32ms/step
# epoch:235 d_loss:0.6221 g_loss:1.4330
# 1/1 [==============================] - 0s 33ms/step
# epoch:236 d_loss:0.5050 g_loss:1.1468
# 1/1 [==============================] - 0s 32ms/step
# epoch:237 d_loss:0.4461 g_loss:1.4718
# 1/1 [==============================] - 0s 33ms/step
# epoch:238 d_loss:0.4618 g_loss:1.4833
# 1/1 [==============================] - 0s 33ms/step
# epoch:239 d_loss:0.4268 g_loss:1.4009
# 1/1 [==============================] - 0s 33ms/step
# epoch:240 d_loss:0.5734 g_loss:1.8097
# 1/1 [==============================] - 0s 32ms/step
# epoch:241 d_loss:0.5425 g_loss:1.8091
# 1/1 [==============================] - 0s 34ms/step
# epoch:242 d_loss:0.4962 g_loss:1.6442
# 1/1 [==============================] - 0s 33ms/step
# epoch:243 d_loss:0.5141 g_loss:1.4358
# 1/1 [==============================] - 0s 33ms/step
# epoch:244 d_loss:0.4731 g_loss:1.8275
# 1/1 [==============================] - 0s 31ms/step
# epoch:245 d_loss:0.4930 g_loss:1.7234
# 1/1 [==============================] - 0s 34ms/step
# epoch:246 d_loss:0.5087 g_loss:1.7336
# 1/1 [==============================] - 0s 32ms/step
# epoch:247 d_loss:0.5203 g_loss:1.7561
# 1/1 [==============================] - 0s 34ms/step
# epoch:248 d_loss:0.5055 g_loss:1.7672
# 1/1 [==============================] - 0s 33ms/step
# epoch:249 d_loss:0.3666 g_loss:1.7239
# 1/1 [==============================] - 0s 32ms/step
# epoch:250 d_loss:0.4270 g_loss:1.5779
# 1/1 [==============================] - 0s 32ms/step
# epoch:251 d_loss:0.5018 g_loss:1.7004
# 1/1 [==============================] - 0s 33ms/step
# epoch:252 d_loss:0.4346 g_loss:1.9366
# 1/1 [==============================] - 0s 32ms/step
# epoch:253 d_loss:0.4191 g_loss:1.7697
# 1/1 [==============================] - 0s 32ms/step
# epoch:254 d_loss:0.2866 g_loss:2.1280
# 1/1 [==============================] - 0s 32ms/step
# epoch:255 d_loss:0.5334 g_loss:2.0193
# 1/1 [==============================] - 0s 31ms/step
# epoch:256 d_loss:0.4330 g_loss:1.8985
# 1/1 [==============================] - 0s 34ms/step
# epoch:257 d_loss:0.3347 g_loss:1.9697
# 1/1 [==============================] - 0s 33ms/step
# epoch:258 d_loss:0.3527 g_loss:2.0336
# 1/1 [==============================] - 0s 32ms/step
# epoch:259 d_loss:0.4556 g_loss:1.7380
# 1/1 [==============================] - 0s 33ms/step
# epoch:260 d_loss:0.3973 g_loss:1.9664
# 1/1 [==============================] - 0s 33ms/step
# epoch:261 d_loss:0.3611 g_loss:2.0760
# 1/1 [==============================] - 0s 32ms/step
# epoch:262 d_loss:0.2726 g_loss:2.4528
# 1/1 [==============================] - 0s 33ms/step
# epoch:263 d_loss:0.4443 g_loss:2.4750
# 1/1 [==============================] - 0s 33ms/step
# epoch:264 d_loss:0.4218 g_loss:2.6299
# 1/1 [==============================] - 0s 33ms/step
# epoch:265 d_loss:0.3743 g_loss:1.8542
# 1/1 [==============================] - 0s 32ms/step
# epoch:266 d_loss:0.4086 g_loss:1.8871
# 1/1 [==============================] - 0s 34ms/step
# epoch:267 d_loss:0.5414 g_loss:1.6546
# 1/1 [==============================] - 0s 33ms/step
# epoch:268 d_loss:0.5583 g_loss:1.7513
# 1/1 [==============================] - 0s 32ms/step
# epoch:269 d_loss:0.4346 g_loss:2.1716
# 1/1 [==============================] - 0s 33ms/step
# epoch:270 d_loss:0.4269 g_loss:2.6452
# 1/1 [==============================] - 0s 33ms/step
# epoch:271 d_loss:0.5279 g_loss:2.1103
# 1/1 [==============================] - 0s 33ms/step
# epoch:272 d_loss:0.5780 g_loss:1.8376
# 1/1 [==============================] - 0s 32ms/step
# epoch:273 d_loss:0.5364 g_loss:2.1479
# 1/1 [==============================] - 0s 32ms/step
# epoch:274 d_loss:0.5398 g_loss:1.9317
# 1/1 [==============================] - 0s 33ms/step
# epoch:275 d_loss:0.3866 g_loss:2.3481
# 1/1 [==============================] - 0s 32ms/step
# epoch:276 d_loss:0.3780 g_loss:2.6503
# 1/1 [==============================] - 0s 34ms/step
# epoch:277 d_loss:0.4698 g_loss:2.2308
# 1/1 [==============================] - 0s 33ms/step
# epoch:278 d_loss:0.4313 g_loss:2.2464
# 1/1 [==============================] - 0s 32ms/step
# epoch:279 d_loss:0.5992 g_loss:2.0095
# 1/1 [==============================] - 0s 33ms/step
# epoch:280 d_loss:0.7160 g_loss:1.4196
# 1/1 [==============================] - 0s 33ms/step
# epoch:281 d_loss:0.5565 g_loss:1.4767
# 1/1 [==============================] - 0s 32ms/step
# epoch:282 d_loss:0.3862 g_loss:2.0150
# 1/1 [==============================] - 0s 33ms/step
# epoch:283 d_loss:0.4672 g_loss:2.2001
# 1/1 [==============================] - 0s 32ms/step
# epoch:284 d_loss:0.6050 g_loss:2.0661
# 1/1 [==============================] - 0s 32ms/step
# epoch:285 d_loss:0.6055 g_loss:1.8448
# 1/1 [==============================] - 0s 33ms/step
# epoch:286 d_loss:0.5287 g_loss:1.6530
# 1/1 [==============================] - 0s 33ms/step
# epoch:287 d_loss:0.4540 g_loss:1.4843
# 1/1 [==============================] - 0s 33ms/step
# epoch:288 d_loss:0.4116 g_loss:1.7575
# 1/1 [==============================] - 0s 32ms/step
# epoch:289 d_loss:0.5458 g_loss:1.3566
# 1/1 [==============================] - 0s 33ms/step
# epoch:290 d_loss:0.4903 g_loss:1.5734
# 1/1 [==============================] - 0s 32ms/step
# epoch:291 d_loss:0.4588 g_loss:2.0772
# 1/1 [==============================] - 0s 31ms/step
# epoch:292 d_loss:0.5520 g_loss:2.2645
# 1/1 [==============================] - 0s 33ms/step
# epoch:293 d_loss:0.6106 g_loss:1.7112
# 1/1 [==============================] - 0s 33ms/step
# epoch:294 d_loss:0.6238 g_loss:1.4810
# 1/1 [==============================] - 0s 33ms/step
# epoch:295 d_loss:0.5369 g_loss:1.5710
# 1/1 [==============================] - 0s 34ms/step
# epoch:296 d_loss:0.5577 g_loss:1.8696
# 1/1 [==============================] - 0s 33ms/step
# epoch:297 d_loss:0.5276 g_loss:1.7711
# 1/1 [==============================] - 0s 33ms/step
# epoch:298 d_loss:0.4860 g_loss:1.8346
# 1/1 [==============================] - 0s 33ms/step
# epoch:299 d_loss:0.4398 g_loss:1.9247
# 1/1 [==============================] - 0s 33ms/step
# epoch:300 d_loss:0.4075 g_loss:1.6927
# 1/1 [==============================] - 0s 34ms/step
# epoch:301 d_loss:0.3719 g_loss:1.8941
# 1/1 [==============================] - 0s 33ms/step
# epoch:302 d_loss:0.5428 g_loss:2.0894
# 1/1 [==============================] - 0s 33ms/step
# epoch:303 d_loss:0.3080 g_loss:1.8778
# 1/1 [==============================] - 0s 32ms/step
# epoch:304 d_loss:0.4905 g_loss:2.0637
# 1/1 [==============================] - 0s 33ms/step
# epoch:305 d_loss:0.2960 g_loss:2.3857
# 1/1 [==============================] - 0s 34ms/step
# epoch:306 d_loss:0.3922 g_loss:2.2975
# 1/1 [==============================] - 0s 33ms/step
# epoch:307 d_loss:0.3849 g_loss:2.1918
# 1/1 [==============================] - 0s 32ms/step
# epoch:308 d_loss:0.4835 g_loss:1.7662
# 1/1 [==============================] - 0s 33ms/step
# epoch:309 d_loss:0.3909 g_loss:1.5859
# 1/1 [==============================] - 0s 33ms/step
# epoch:310 d_loss:0.4547 g_loss:2.0674
# 1/1 [==============================] - 0s 33ms/step
# epoch:311 d_loss:0.4897 g_loss:1.5064
# 1/1 [==============================] - 0s 33ms/step
# epoch:312 d_loss:0.3683 g_loss:2.1598
# 1/1 [==============================] - 0s 33ms/step
# epoch:313 d_loss:0.4272 g_loss:2.5311
# 1/1 [==============================] - 0s 32ms/step
# epoch:314 d_loss:0.5641 g_loss:2.1825
# 1/1 [==============================] - 0s 32ms/step
# epoch:315 d_loss:0.5337 g_loss:1.7773
# 1/1 [==============================] - 0s 34ms/step
# epoch:316 d_loss:0.4892 g_loss:1.6351
# 1/1 [==============================] - 0s 34ms/step
# epoch:317 d_loss:0.5783 g_loss:1.3823
# 1/1 [==============================] - 0s 33ms/step
# epoch:318 d_loss:0.4253 g_loss:1.4896
# 1/1 [==============================] - 0s 38ms/step
# epoch:319 d_loss:0.5243 g_loss:1.6910
# 1/1 [==============================] - 0s 33ms/step
# epoch:320 d_loss:0.3457 g_loss:2.1167
# 1/1 [==============================] - 0s 32ms/step
# epoch:321 d_loss:0.3700 g_loss:2.5388
# 1/1 [==============================] - 0s 32ms/step
# epoch:322 d_loss:0.5318 g_loss:1.9947
# 1/1 [==============================] - 0s 34ms/step
# epoch:323 d_loss:0.4069 g_loss:1.7457
# 1/1 [==============================] - 0s 37ms/step
# epoch:324 d_loss:0.4489 g_loss:1.7086
# 1/1 [==============================] - 0s 32ms/step
# epoch:325 d_loss:0.4048 g_loss:1.9058
# 1/1 [==============================] - 0s 34ms/step
# epoch:326 d_loss:0.3701 g_loss:2.6273
# 1/1 [==============================] - 0s 35ms/step
# epoch:327 d_loss:0.4567 g_loss:2.0701
# 1/1 [==============================] - 0s 32ms/step
# epoch:328 d_loss:0.3161 g_loss:2.0547
# 1/1 [==============================] - 0s 33ms/step
# epoch:329 d_loss:0.3877 g_loss:1.8244
# 1/1 [==============================] - 0s 33ms/step
# epoch:330 d_loss:0.4333 g_loss:2.4644
# 1/1 [==============================] - 0s 32ms/step
# epoch:331 d_loss:0.3212 g_loss:2.7370
# 1/1 [==============================] - 0s 32ms/step
# epoch:332 d_loss:0.3013 g_loss:2.7113
# 1/1 [==============================] - 0s 32ms/step
# epoch:333 d_loss:0.3222 g_loss:2.8381
# 1/1 [==============================] - 0s 33ms/step
# epoch:334 d_loss:0.4249 g_loss:2.1641
# 1/1 [==============================] - 0s 33ms/step
# epoch:335 d_loss:0.4704 g_loss:2.0684
# 1/1 [==============================] - 0s 33ms/step
# epoch:336 d_loss:0.4100 g_loss:2.5501
# 1/1 [==============================] - 0s 33ms/step
# epoch:337 d_loss:0.2375 g_loss:2.2431
# 1/1 [==============================] - 0s 33ms/step
# epoch:338 d_loss:0.4507 g_loss:2.5522
# 1/1 [==============================] - 0s 33ms/step
# epoch:339 d_loss:0.4142 g_loss:2.9263
# 1/1 [==============================] - 0s 33ms/step
# epoch:340 d_loss:0.4554 g_loss:2.1526
# 1/1 [==============================] - 0s 33ms/step
# epoch:341 d_loss:0.4966 g_loss:1.7057
# 1/1 [==============================] - 0s 33ms/step
# epoch:342 d_loss:0.5346 g_loss:1.5253
# 1/1 [==============================] - 0s 32ms/step
# epoch:343 d_loss:0.5353 g_loss:1.7367
# 1/1 [==============================] - 0s 32ms/step
# epoch:344 d_loss:0.3486 g_loss:2.4310
# 1/1 [==============================] - 0s 32ms/step
# epoch:345 d_loss:0.4211 g_loss:2.1096
# 1/1 [==============================] - 0s 33ms/step
# epoch:346 d_loss:0.4519 g_loss:1.9714
# 1/1 [==============================] - 0s 32ms/step
# epoch:347 d_loss:0.4201 g_loss:1.9879
# 1/1 [==============================] - 0s 33ms/step
# epoch:348 d_loss:0.5717 g_loss:1.7037
# 1/1 [==============================] - 0s 33ms/step
# epoch:349 d_loss:0.5164 g_loss:1.3755
# 1/1 [==============================] - 0s 33ms/step
# epoch:350 d_loss:0.4605 g_loss:1.4545
# 1/1 [==============================] - 0s 33ms/step
# epoch:351 d_loss:0.3898 g_loss:2.0234
# 1/1 [==============================] - 0s 34ms/step
# epoch:352 d_loss:0.4470 g_loss:2.2842
# 1/1 [==============================] - 0s 33ms/step
# epoch:353 d_loss:0.4045 g_loss:2.5177
# 1/1 [==============================] - 0s 33ms/step
# epoch:354 d_loss:0.4928 g_loss:2.5637
# 1/1 [==============================] - 0s 33ms/step
# epoch:355 d_loss:0.4375 g_loss:2.2487
# 1/1 [==============================] - 0s 34ms/step
# epoch:356 d_loss:0.4877 g_loss:2.1427
# 1/1 [==============================] - 0s 34ms/step
# epoch:357 d_loss:0.5278 g_loss:1.5785
# 1/1 [==============================] - 0s 33ms/step
# epoch:358 d_loss:0.4411 g_loss:1.6107
# 1/1 [==============================] - 0s 33ms/step
# epoch:359 d_loss:0.3707 g_loss:1.8192
# 1/1 [==============================] - 0s 33ms/step
# epoch:360 d_loss:0.5086 g_loss:2.0357
# 1/1 [==============================] - 0s 32ms/step
# epoch:361 d_loss:0.3674 g_loss:1.7690
# 1/1 [==============================] - 0s 32ms/step
# epoch:362 d_loss:0.4055 g_loss:2.0068
# 1/1 [==============================] - 0s 32ms/step
# epoch:363 d_loss:0.5032 g_loss:1.6858
# 1/1 [==============================] - 0s 33ms/step
# epoch:364 d_loss:0.4693 g_loss:1.5556
# 1/1 [==============================] - 0s 33ms/step
# epoch:365 d_loss:0.3819 g_loss:1.9034
# 1/1 [==============================] - 0s 32ms/step
# epoch:366 d_loss:0.4096 g_loss:1.6257
# 1/1 [==============================] - 0s 33ms/step
# epoch:367 d_loss:0.3154 g_loss:1.7237
# 1/1 [==============================] - 0s 33ms/step
# epoch:368 d_loss:0.3145 g_loss:2.0251
# 1/1 [==============================] - 0s 33ms/step
# epoch:369 d_loss:0.3695 g_loss:2.0784
# 1/1 [==============================] - 0s 33ms/step
# epoch:370 d_loss:0.3423 g_loss:2.1429
# 1/1 [==============================] - 0s 34ms/step
# epoch:371 d_loss:0.2851 g_loss:2.2884
# 1/1 [==============================] - 0s 33ms/step
# epoch:372 d_loss:0.3098 g_loss:1.7358
# 1/1 [==============================] - 0s 32ms/step
# epoch:373 d_loss:0.2892 g_loss:1.8139
# 1/1 [==============================] - 0s 43ms/step
# epoch:374 d_loss:0.3353 g_loss:1.5534
# 1/1 [==============================] - 0s 34ms/step
# epoch:375 d_loss:0.2992 g_loss:2.0678
# 1/1 [==============================] - 0s 31ms/step
# epoch:376 d_loss:0.3476 g_loss:2.2290
# 1/1 [==============================] - 0s 33ms/step
# epoch:377 d_loss:0.2659 g_loss:2.3400
# 1/1 [==============================] - 0s 34ms/step
# epoch:378 d_loss:0.3542 g_loss:2.1961
# 1/1 [==============================] - 0s 33ms/step
# epoch:379 d_loss:0.2942 g_loss:1.8430
# 1/1 [==============================] - 0s 33ms/step
# epoch:380 d_loss:0.3415 g_loss:1.8427
# 1/1 [==============================] - 0s 33ms/step
# epoch:381 d_loss:0.4009 g_loss:1.7238
# 1/1 [==============================] - 0s 32ms/step
# epoch:382 d_loss:0.4061 g_loss:1.9878
# 1/1 [==============================] - 0s 32ms/step
# epoch:383 d_loss:0.4233 g_loss:2.1777
# 1/1 [==============================] - 0s 33ms/step
# epoch:384 d_loss:0.3893 g_loss:1.7704
# 1/1 [==============================] - 0s 32ms/step
# epoch:385 d_loss:0.3914 g_loss:1.9514
# 1/1 [==============================] - 0s 32ms/step
# epoch:386 d_loss:0.3547 g_loss:2.1210
# 1/1 [==============================] - 0s 33ms/step
# epoch:387 d_loss:0.3033 g_loss:2.3596
# 1/1 [==============================] - 0s 35ms/step
# epoch:388 d_loss:0.5282 g_loss:1.6145
# 1/1 [==============================] - 0s 33ms/step
# epoch:389 d_loss:0.4361 g_loss:1.4480
# 1/1 [==============================] - 0s 32ms/step
# epoch:390 d_loss:0.2735 g_loss:1.8665
# 1/1 [==============================] - 0s 33ms/step
# epoch:391 d_loss:0.3874 g_loss:1.8277
# 1/1 [==============================] - 0s 33ms/step
# epoch:392 d_loss:0.3495 g_loss:2.2128
# 1/1 [==============================] - 0s 32ms/step
# epoch:393 d_loss:0.3560 g_loss:1.8443
# 1/1 [==============================] - 0s 32ms/step
# epoch:394 d_loss:0.5328 g_loss:1.6188
# 1/1 [==============================] - 0s 33ms/step
# epoch:395 d_loss:0.4297 g_loss:1.7656
# 1/1 [==============================] - 0s 33ms/step
# epoch:396 d_loss:0.4300 g_loss:1.5360
# 1/1 [==============================] - 0s 34ms/step
# epoch:397 d_loss:0.5197 g_loss:2.1549
# 1/1 [==============================] - 0s 32ms/step
# epoch:398 d_loss:0.4808 g_loss:2.0032
# 1/1 [==============================] - 0s 33ms/step
# epoch:399 d_loss:0.4674 g_loss:1.7190
# 1/1 [==============================] - 0s 33ms/step
# epoch:400 d_loss:0.4407 g_loss:1.5443
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# epoch:401 d_loss:0.3899 g_loss:1.7930
# 1/1 [==============================] - 0s 33ms/step
# epoch:402 d_loss:0.4159 g_loss:1.8990
# 1/1 [==============================] - 0s 34ms/step
# epoch:403 d_loss:0.6442 g_loss:1.5115
# 1/1 [==============================] - 0s 35ms/step
# epoch:404 d_loss:0.4037 g_loss:1.6042
# 1/1 [==============================] - 0s 32ms/step
# epoch:405 d_loss:0.3990 g_loss:1.4238
# 1/1 [==============================] - 0s 34ms/step
# epoch:406 d_loss:0.4649 g_loss:1.8839
# 1/1 [==============================] - 0s 34ms/step
# epoch:407 d_loss:0.4970 g_loss:1.8988
# 1/1 [==============================] - 0s 34ms/step
# epoch:408 d_loss:0.3905 g_loss:2.1732
# 1/1 [==============================] - 0s 34ms/step
# epoch:409 d_loss:0.3078 g_loss:2.7771
# 1/1 [==============================] - 0s 34ms/step
# epoch:410 d_loss:0.2832 g_loss:2.7433
# 1/1 [==============================] - 0s 34ms/step
# epoch:411 d_loss:0.2141 g_loss:2.7476
# 1/1 [==============================] - 0s 33ms/step
# epoch:412 d_loss:0.3548 g_loss:2.9433
# 1/1 [==============================] - 0s 33ms/step
# epoch:413 d_loss:0.2190 g_loss:2.7434
# 1/1 [==============================] - 0s 33ms/step
# epoch:414 d_loss:0.1345 g_loss:2.7908
# 1/1 [==============================] - 0s 33ms/step
# epoch:415 d_loss:0.2507 g_loss:2.6157
# 1/1 [==============================] - 0s 33ms/step
# epoch:416 d_loss:0.3966 g_loss:1.9776
# 1/1 [==============================] - 0s 34ms/step
# epoch:417 d_loss:0.2139 g_loss:2.4599
# 1/1 [==============================] - 0s 34ms/step
# epoch:418 d_loss:0.2535 g_loss:2.4173
# 1/1 [==============================] - 0s 33ms/step
# epoch:419 d_loss:0.2010 g_loss:2.6260
# 1/1 [==============================] - 0s 33ms/step
# epoch:420 d_loss:0.1573 g_loss:3.3590
# 1/1 [==============================] - 0s 33ms/step
# epoch:421 d_loss:0.2613 g_loss:3.4674
# 1/1 [==============================] - 0s 34ms/step
# epoch:422 d_loss:0.3909 g_loss:2.9011
# 1/1 [==============================] - 0s 33ms/step
# epoch:423 d_loss:0.2976 g_loss:2.5147
# 1/1 [==============================] - 0s 33ms/step
# epoch:424 d_loss:0.2289 g_loss:2.5029
# 1/1 [==============================] - 0s 34ms/step
# epoch:425 d_loss:0.3194 g_loss:2.3230
# 1/1 [==============================] - 0s 34ms/step
# epoch:426 d_loss:0.4336 g_loss:2.1337
# 1/1 [==============================] - 0s 34ms/step
# epoch:427 d_loss:0.2163 g_loss:3.1896
# 1/1 [==============================] - 0s 34ms/step
# epoch:428 d_loss:0.4118 g_loss:2.9949
# 1/1 [==============================] - 0s 33ms/step
# epoch:429 d_loss:0.3365 g_loss:3.1648
# 1/1 [==============================] - 0s 33ms/step
# epoch:430 d_loss:0.3397 g_loss:2.4658
# 1/1 [==============================] - 0s 33ms/step
# epoch:431 d_loss:0.3709 g_loss:2.0189
# 1/1 [==============================] - 0s 34ms/step
# epoch:432 d_loss:0.3485 g_loss:2.1869
# 1/1 [==============================] - 0s 32ms/step
# epoch:433 d_loss:0.3598 g_loss:2.4145
# 1/1 [==============================] - 0s 33ms/step
# epoch:434 d_loss:0.2350 g_loss:2.6522
# 1/1 [==============================] - 0s 33ms/step
# epoch:435 d_loss:0.4630 g_loss:2.6064
# 1/1 [==============================] - 0s 32ms/step
# epoch:436 d_loss:0.5137 g_loss:2.5316
# 1/1 [==============================] - 0s 33ms/step
# epoch:437 d_loss:0.3263 g_loss:2.0921
# 1/1 [==============================] - 0s 34ms/step
# epoch:438 d_loss:0.3548 g_loss:2.1407
# 1/1 [==============================] - 0s 34ms/step
# epoch:439 d_loss:0.4007 g_loss:2.3499
# 1/1 [==============================] - 0s 34ms/step
# epoch:440 d_loss:0.3977 g_loss:1.7509
# 1/1 [==============================] - 0s 34ms/step
# epoch:441 d_loss:0.3183 g_loss:2.4384
# 1/1 [==============================] - 0s 34ms/step
# epoch:442 d_loss:0.3720 g_loss:2.4624
# 1/1 [==============================] - 0s 34ms/step
# epoch:443 d_loss:0.3714 g_loss:2.5930
# 1/1 [==============================] - 0s 33ms/step
# epoch:444 d_loss:0.3988 g_loss:2.2328
# 1/1 [==============================] - 0s 33ms/step
# epoch:445 d_loss:0.4085 g_loss:1.9873
# 1/1 [==============================] - 0s 31ms/step
# epoch:446 d_loss:0.3923 g_loss:1.7173
# 1/1 [==============================] - 0s 34ms/step
# epoch:447 d_loss:0.5564 g_loss:1.5692
# 1/1 [==============================] - 0s 34ms/step
# epoch:448 d_loss:0.4371 g_loss:2.1421
# 1/1 [==============================] - 0s 32ms/step
# epoch:449 d_loss:0.3341 g_loss:2.8318
# 1/1 [==============================] - 0s 32ms/step
# epoch:450 d_loss:0.4222 g_loss:2.6242
# 1/1 [==============================] - 0s 33ms/step
# epoch:451 d_loss:0.4218 g_loss:2.3475
# 1/1 [==============================] - 0s 32ms/step
# epoch:452 d_loss:0.4588 g_loss:2.1098
# 1/1 [==============================] - 0s 33ms/step
# epoch:453 d_loss:0.4312 g_loss:1.7038
# 1/1 [==============================] - 0s 32ms/step
# epoch:454 d_loss:0.3481 g_loss:1.7777
# 1/1 [==============================] - 0s 33ms/step
# epoch:455 d_loss:0.3584 g_loss:2.4993
# 1/1 [==============================] - 0s 33ms/step
# epoch:456 d_loss:0.3445 g_loss:2.7047
# 1/1 [==============================] - 0s 33ms/step
# epoch:457 d_loss:0.4304 g_loss:1.8139
# 1/1 [==============================] - 0s 33ms/step
# epoch:458 d_loss:0.3150 g_loss:2.4337
# 1/1 [==============================] - 0s 34ms/step
# epoch:459 d_loss:0.2546 g_loss:2.1807
# 1/1 [==============================] - 0s 33ms/step
# epoch:460 d_loss:0.2266 g_loss:2.3635
# 1/1 [==============================] - 0s 33ms/step
# epoch:461 d_loss:0.3488 g_loss:2.0013
# 1/1 [==============================] - 0s 33ms/step
# epoch:462 d_loss:0.2642 g_loss:2.5648
# 1/1 [==============================] - 0s 32ms/step
# epoch:463 d_loss:0.2394 g_loss:2.2998
# 1/1 [==============================] - 0s 33ms/step
# epoch:464 d_loss:0.2464 g_loss:2.3401
# 1/1 [==============================] - 0s 33ms/step
# epoch:465 d_loss:0.2809 g_loss:1.8754
# 1/1 [==============================] - 0s 34ms/step
# epoch:466 d_loss:0.3104 g_loss:2.5227
# 1/1 [==============================] - 0s 35ms/step
# epoch:467 d_loss:0.2800 g_loss:2.7138
# 1/1 [==============================] - 0s 33ms/step
# epoch:468 d_loss:0.2070 g_loss:3.4662
# 1/1 [==============================] - 0s 34ms/step
# epoch:469 d_loss:0.2208 g_loss:2.5647
# 1/1 [==============================] - 0s 33ms/step
# epoch:470 d_loss:0.2913 g_loss:2.7620
# 1/1 [==============================] - 0s 33ms/step
# epoch:471 d_loss:0.2062 g_loss:2.1641
# 1/1 [==============================] - 0s 34ms/step
# epoch:472 d_loss:0.2391 g_loss:1.9353
# 1/1 [==============================] - 0s 36ms/step
# epoch:473 d_loss:0.2164 g_loss:2.2524
# 1/1 [==============================] - 0s 35ms/step
# epoch:474 d_loss:0.2899 g_loss:2.4342
# 1/1 [==============================] - 0s 33ms/step
# epoch:475 d_loss:0.3450 g_loss:2.6422
# 1/1 [==============================] - 0s 35ms/step
# epoch:476 d_loss:0.2622 g_loss:2.4267
# 1/1 [==============================] - 0s 36ms/step
# epoch:477 d_loss:0.1769 g_loss:2.6531
# 1/1 [==============================] - 0s 35ms/step
# epoch:478 d_loss:0.2374 g_loss:2.2498
# 1/1 [==============================] - 0s 33ms/step
# epoch:479 d_loss:0.1461 g_loss:2.6278
# 1/1 [==============================] - 0s 33ms/step
# epoch:480 d_loss:0.2136 g_loss:2.4786
# 1/1 [==============================] - 0s 34ms/step
# epoch:481 d_loss:0.1917 g_loss:2.7386
# 1/1 [==============================] - 0s 33ms/step
# epoch:482 d_loss:0.2933 g_loss:2.8415
# 1/1 [==============================] - 0s 36ms/step
# epoch:483 d_loss:0.1403 g_loss:2.4221
# 1/1 [==============================] - 0s 34ms/step
# epoch:484 d_loss:0.1434 g_loss:2.9347
# 1/1 [==============================] - 0s 34ms/step
# epoch:485 d_loss:0.1382 g_loss:3.1758
# 1/1 [==============================] - 0s 32ms/step
# epoch:486 d_loss:0.1143 g_loss:3.5609
# 1/1 [==============================] - 0s 33ms/step
# epoch:487 d_loss:0.2275 g_loss:3.7450
# 1/1 [==============================] - 0s 35ms/step
# epoch:488 d_loss:0.1837 g_loss:3.6375
# 1/1 [==============================] - 0s 33ms/step
# epoch:489 d_loss:0.2247 g_loss:3.4808
# 1/1 [==============================] - 0s 32ms/step
# epoch:490 d_loss:0.2371 g_loss:3.2342
# 1/1 [==============================] - 0s 34ms/step
# epoch:491 d_loss:0.1331 g_loss:3.4554
# 1/1 [==============================] - 0s 33ms/step
# epoch:492 d_loss:0.1338 g_loss:3.7492
# 1/1 [==============================] - 0s 33ms/step
# epoch:493 d_loss:0.2784 g_loss:3.0395
# 1/1 [==============================] - 0s 33ms/step
# epoch:494 d_loss:0.2402 g_loss:3.5495
# 1/1 [==============================] - 0s 34ms/step
# epoch:495 d_loss:0.1569 g_loss:3.6429
# 1/1 [==============================] - 0s 34ms/step
# epoch:496 d_loss:0.1674 g_loss:4.5148
# 1/1 [==============================] - 0s 32ms/step
# epoch:497 d_loss:0.2269 g_loss:2.9110
# 1/1 [==============================] - 0s 34ms/step
# epoch:498 d_loss:0.1440 g_loss:3.5541
# 1/1 [==============================] - 0s 34ms/step
# epoch:499 d_loss:0.2746 g_loss:2.7397
# 1/1 [==============================] - 0s 34ms/step
# epoch:500 d_loss:0.2580 g_loss:2.6644
# 1/1 [==============================] - 0s 32ms/step
# epoch:501 d_loss:0.1424 g_loss:3.3405
# 1/1 [==============================] - 0s 35ms/step
# epoch:502 d_loss:0.1899 g_loss:3.7276
# 1/1 [==============================] - 0s 34ms/step
# epoch:503 d_loss:0.4879 g_loss:2.2176
# 1/1 [==============================] - 0s 33ms/step
# epoch:504 d_loss:0.2525 g_loss:3.0533
# 1/1 [==============================] - 0s 32ms/step
# epoch:505 d_loss:0.4411 g_loss:3.1843
# 1/1 [==============================] - 0s 33ms/step
# epoch:506 d_loss:0.3065 g_loss:2.5806
# 1/1 [==============================] - 0s 33ms/step
# epoch:507 d_loss:0.2897 g_loss:2.4417
# 1/1 [==============================] - 0s 33ms/step
# epoch:508 d_loss:0.3471 g_loss:2.2890
# 1/1 [==============================] - 0s 32ms/step
# epoch:509 d_loss:0.3720 g_loss:2.7452
# 1/1 [==============================] - 0s 33ms/step
# epoch:510 d_loss:0.2960 g_loss:3.0806
# 1/1 [==============================] - 0s 33ms/step
# epoch:511 d_loss:0.3709 g_loss:2.7976
# 1/1 [==============================] - 0s 33ms/step
# epoch:512 d_loss:0.2244 g_loss:2.8312
# 1/1 [==============================] - 0s 33ms/step
# epoch:513 d_loss:0.4647 g_loss:1.9782
# 1/1 [==============================] - 0s 34ms/step
# epoch:514 d_loss:0.3189 g_loss:2.5578
# 1/1 [==============================] - 0s 33ms/step
# epoch:515 d_loss:0.2687 g_loss:3.4521
# 1/1 [==============================] - 0s 33ms/step
# epoch:516 d_loss:0.4675 g_loss:2.7650
# 1/1 [==============================] - 0s 33ms/step
# epoch:517 d_loss:0.4572 g_loss:2.6828
# 1/1 [==============================] - 0s 33ms/step
# epoch:518 d_loss:0.2371 g_loss:2.8870
# 1/1 [==============================] - 0s 33ms/step
# epoch:519 d_loss:0.4428 g_loss:2.4805
# 1/1 [==============================] - 0s 34ms/step
# epoch:520 d_loss:0.3760 g_loss:2.3663
# 1/1 [==============================] - 0s 34ms/step
# epoch:521 d_loss:0.3412 g_loss:2.0466
# 1/1 [==============================] - 0s 33ms/step
# epoch:522 d_loss:0.3296 g_loss:2.1958
# 1/1 [==============================] - 0s 34ms/step
# epoch:523 d_loss:0.2591 g_loss:2.6160
# 1/1 [==============================] - 0s 33ms/step
# epoch:524 d_loss:0.2974 g_loss:3.0009
# 1/1 [==============================] - 0s 34ms/step
# epoch:525 d_loss:0.2976 g_loss:2.8598
# 1/1 [==============================] - 0s 34ms/step
# epoch:526 d_loss:0.2167 g_loss:2.4553
# 1/1 [==============================] - 0s 33ms/step
# epoch:527 d_loss:0.2439 g_loss:2.4117
# 1/1 [==============================] - 0s 35ms/step
# epoch:528 d_loss:0.1779 g_loss:3.1278
# 1/1 [==============================] - 0s 33ms/step
# epoch:529 d_loss:0.1259 g_loss:3.2772
# 1/1 [==============================] - 0s 34ms/step
# epoch:530 d_loss:0.1365 g_loss:3.4993
# 1/1 [==============================] - 0s 33ms/step
# epoch:531 d_loss:0.1205 g_loss:3.5437
# 1/1 [==============================] - 0s 33ms/step
# ...
# 1/1 [==============================] - 0s 33ms/step
# epoch:3830 d_loss:0.5971 g_loss:1.6694
# 1/1 [==============================] - 0s 33ms/step
# epoch:3831 d_loss:0.7014 g_loss:1.1970
# 1/1 [==============================] - 0s 33ms/step
# epoch:3832 d_loss:0.6340 g_loss:1.3177
# 1/1 [==============================] - 0s 33ms/step
# epoch:3833 d_loss:0.4902 g_loss:1.5630
# 1/1 [==============================] - 0s 33ms/step
# epoch:3834 d_loss:0.5050 g_loss:1.3828
# 1/1 [==============================] - 0s 33ms/step
# epoch:3835 d_loss:0.4726 g_loss:1.6533
# 1/1 [==============================] - 0s 33ms/step
# epoch:3836 d_loss:0.5664 g_loss:1.8882
# 1/1 [==============================] - 0s 32ms/step
# epoch:3837 d_loss:0.5476 g_loss:2.1352
# 1/1 [==============================] - 0s 33ms/step
# epoch:3838 d_loss:0.5227 g_loss:1.6699
# 1/1 [==============================] - 0s 33ms/step
# epoch:3839 d_loss:0.4889 g_loss:1.7229
# 1/1 [==============================] - 0s 33ms/step
# epoch:3840 d_loss:0.4005 g_loss:1.5460
# 1/1 [==============================] - 0s 34ms/step
# epoch:3841 d_loss:0.5683 g_loss:1.4362
# 1/1 [==============================] - 0s 33ms/step
# epoch:3842 d_loss:0.4429 g_loss:1.5215
# 1/1 [==============================] - 0s 33ms/step
# epoch:3843 d_loss:0.3050 g_loss:1.4286
# 1/1 [==============================] - 0s 31ms/step
# epoch:3844 d_loss:0.4070 g_loss:1.8318
# 1/1 [==============================] - 0s 32ms/step
# epoch:3845 d_loss:0.4735 g_loss:1.6074
# 1/1 [==============================] - 0s 33ms/step
# epoch:3846 d_loss:0.3501 g_loss:1.5892
# 1/1 [==============================] - 0s 32ms/step
# epoch:3847 d_loss:0.4059 g_loss:2.1373
# 1/1 [==============================] - 0s 32ms/step
# epoch:3848 d_loss:0.4832 g_loss:2.1844
# 1/1 [==============================] - 0s 34ms/step
# epoch:3849 d_loss:0.4666 g_loss:1.9117
# 1/1 [==============================] - 0s 33ms/step
# epoch:3850 d_loss:0.3990 g_loss:1.6678
# 1/1 [==============================] - 0s 32ms/step
# epoch:3851 d_loss:0.4091 g_loss:1.4370
# 1/1 [==============================] - 0s 33ms/step
# epoch:3852 d_loss:0.5249 g_loss:1.3653
# 1/1 [==============================] - 0s 33ms/step
# epoch:3853 d_loss:0.5011 g_loss:1.9360
# 1/1 [==============================] - 0s 34ms/step
# epoch:3854 d_loss:0.4047 g_loss:2.1826
# 1/1 [==============================] - 0s 33ms/step
# epoch:3855 d_loss:0.4691 g_loss:2.2416
# 1/1 [==============================] - 0s 33ms/step
# epoch:3856 d_loss:0.5268 g_loss:2.0049
# 1/1 [==============================] - 0s 32ms/step
# epoch:3857 d_loss:0.4511 g_loss:2.2222
# 1/1 [==============================] - 0s 33ms/step
# epoch:3858 d_loss:0.6265 g_loss:1.8607
# 1/1 [==============================] - 0s 32ms/step
# epoch:3859 d_loss:0.4403 g_loss:1.8452
# 1/1 [==============================] - 0s 33ms/step
# epoch:3860 d_loss:0.4052 g_loss:2.1773
# 1/1 [==============================] - 0s 33ms/step
# epoch:3861 d_loss:0.5071 g_loss:1.9825
# 1/1 [==============================] - 0s 32ms/step
# epoch:3862 d_loss:0.5664 g_loss:1.5723
# 1/1 [==============================] - 0s 34ms/step
# epoch:3863 d_loss:0.6655 g_loss:1.3581
# 1/1 [==============================] - 0s 33ms/step
# epoch:3864 d_loss:0.6385 g_loss:1.7639
# 1/1 [==============================] - 0s 34ms/step
# epoch:3865 d_loss:0.6468 g_loss:1.4552
# 1/1 [==============================] - 0s 34ms/step
# epoch:3866 d_loss:0.4115 g_loss:1.3883
# 1/1 [==============================] - 0s 32ms/step
# epoch:3867 d_loss:0.4266 g_loss:2.0102
# 1/1 [==============================] - 0s 33ms/step
# epoch:3868 d_loss:0.3836 g_loss:2.3273
# 1/1 [==============================] - 0s 34ms/step
# epoch:3869 d_loss:0.4855 g_loss:1.7473
# 1/1 [==============================] - 0s 35ms/step
# epoch:3870 d_loss:0.4933 g_loss:2.0009
# 1/1 [==============================] - 0s 35ms/step
# epoch:3871 d_loss:0.4787 g_loss:1.6697
# 1/1 [==============================] - 0s 33ms/step
# epoch:3872 d_loss:0.4431 g_loss:1.5945
# 1/1 [==============================] - 0s 33ms/step
# epoch:3873 d_loss:0.4300 g_loss:1.7862
# 1/1 [==============================] - 0s 33ms/step
# epoch:3874 d_loss:0.4875 g_loss:1.6955
# 1/1 [==============================] - 0s 32ms/step
# epoch:3875 d_loss:0.5339 g_loss:1.8398
# 1/1 [==============================] - 0s 33ms/step
# epoch:3876 d_loss:0.4579 g_loss:1.9108
# 1/1 [==============================] - 0s 33ms/step
# epoch:3877 d_loss:0.4321 g_loss:1.8675
# 1/1 [==============================] - 0s 33ms/step
# epoch:3878 d_loss:0.4101 g_loss:1.6176
# 1/1 [==============================] - 0s 34ms/step
# epoch:3879 d_loss:0.3883 g_loss:1.9454
# 1/1 [==============================] - 0s 33ms/step
# epoch:3880 d_loss:0.4321 g_loss:1.6006
# 1/1 [==============================] - 0s 32ms/step
# epoch:3881 d_loss:0.4365 g_loss:2.1033
# 1/1 [==============================] - 0s 34ms/step
# epoch:3882 d_loss:0.4796 g_loss:1.8655
# 1/1 [==============================] - 0s 32ms/step
# epoch:3883 d_loss:0.5043 g_loss:1.4751
# 1/1 [==============================] - 0s 33ms/step
# epoch:3884 d_loss:0.4692 g_loss:1.9335
# 1/1 [==============================] - 0s 33ms/step
# epoch:3885 d_loss:0.4996 g_loss:1.9124
# 1/1 [==============================] - 0s 33ms/step
# epoch:3886 d_loss:0.4531 g_loss:2.1195
# 1/1 [==============================] - 0s 33ms/step
# epoch:3887 d_loss:0.4547 g_loss:2.1136
# 1/1 [==============================] - 0s 34ms/step
# epoch:3888 d_loss:0.4838 g_loss:2.0165
# 1/1 [==============================] - 0s 33ms/step
# epoch:3889 d_loss:0.5434 g_loss:1.9257
# 1/1 [==============================] - 0s 32ms/step
# epoch:3890 d_loss:0.5057 g_loss:1.6046
# 1/1 [==============================] - 0s 33ms/step
# epoch:3891 d_loss:0.4595 g_loss:1.6414
# 1/1 [==============================] - 0s 32ms/step
# epoch:3892 d_loss:0.4159 g_loss:1.8639
# 1/1 [==============================] - 0s 33ms/step
# epoch:3893 d_loss:0.5557 g_loss:1.7415
# 1/1 [==============================] - 0s 33ms/step
# epoch:3894 d_loss:0.6299 g_loss:1.6942
# 1/1 [==============================] - 0s 33ms/step
# epoch:3895 d_loss:0.5723 g_loss:1.6731
# 1/1 [==============================] - 0s 34ms/step
# epoch:3896 d_loss:0.5794 g_loss:1.5367
# 1/1 [==============================] - 0s 33ms/step
# epoch:3897 d_loss:0.4916 g_loss:1.4583
# 1/1 [==============================] - 0s 34ms/step
# epoch:3898 d_loss:0.3638 g_loss:1.6747
# 1/1 [==============================] - 0s 32ms/step
# epoch:3899 d_loss:0.4096 g_loss:1.8857
# 1/1 [==============================] - 0s 32ms/step
# epoch:3900 d_loss:0.3066 g_loss:2.0896
# 1/1 [==============================] - 0s 33ms/step
# epoch:3901 d_loss:0.4739 g_loss:1.7519
# 1/1 [==============================] - 0s 32ms/step
# epoch:3902 d_loss:0.6208 g_loss:1.5599
# 1/1 [==============================] - 0s 33ms/step
# epoch:3903 d_loss:0.4298 g_loss:1.6194
# 1/1 [==============================] - 0s 33ms/step
# epoch:3904 d_loss:0.3784 g_loss:1.9902
# 1/1 [==============================] - 0s 33ms/step
# epoch:3905 d_loss:0.4424 g_loss:1.7360
# 1/1 [==============================] - 0s 33ms/step
# epoch:3906 d_loss:0.4266 g_loss:2.0782
# 1/1 [==============================] - 0s 33ms/step
# epoch:3907 d_loss:0.4071 g_loss:1.7848
# 1/1 [==============================] - 0s 33ms/step
# epoch:3908 d_loss:0.4879 g_loss:1.7363
# 1/1 [==============================] - 0s 33ms/step
# epoch:3909 d_loss:0.4418 g_loss:1.8478
# 1/1 [==============================] - 0s 32ms/step
# epoch:3910 d_loss:0.3683 g_loss:2.3668
# 1/1 [==============================] - 0s 33ms/step
# epoch:3911 d_loss:0.4707 g_loss:2.3788
# 1/1 [==============================] - 0s 32ms/step
# epoch:3912 d_loss:0.5028 g_loss:1.8464
# 1/1 [==============================] - 0s 37ms/step
# epoch:3913 d_loss:0.4550 g_loss:2.1719
# 1/1 [==============================] - 0s 33ms/step
# epoch:3914 d_loss:0.4651 g_loss:2.0003
# 1/1 [==============================] - 0s 33ms/step
# epoch:3915 d_loss:0.4918 g_loss:2.1390
# 1/1 [==============================] - 0s 33ms/step
# epoch:3916 d_loss:0.5382 g_loss:1.9504
# 1/1 [==============================] - 0s 32ms/step
# epoch:3917 d_loss:0.4390 g_loss:1.8115
# 1/1 [==============================] - 0s 33ms/step
# epoch:3918 d_loss:0.5678 g_loss:1.5391
# 1/1 [==============================] - 0s 33ms/step
# epoch:3919 d_loss:0.5875 g_loss:1.4347
# 1/1 [==============================] - 0s 33ms/step
# epoch:3920 d_loss:0.4259 g_loss:2.0769
# 1/1 [==============================] - 0s 32ms/step
# epoch:3921 d_loss:0.6528 g_loss:1.7467
# 1/1 [==============================] - 0s 32ms/step
# epoch:3922 d_loss:0.6109 g_loss:1.6129
# 1/1 [==============================] - 0s 34ms/step
# epoch:3923 d_loss:0.6862 g_loss:1.6227
# 1/1 [==============================] - 0s 33ms/step
# epoch:3924 d_loss:0.7687 g_loss:1.7779
# 1/1 [==============================] - 0s 32ms/step
# epoch:3925 d_loss:0.5821 g_loss:1.6170
# 1/1 [==============================] - 0s 33ms/step
# epoch:3926 d_loss:0.7333 g_loss:1.3059
# 1/1 [==============================] - 0s 33ms/step
# epoch:3927 d_loss:0.6135 g_loss:1.6837
# 1/1 [==============================] - 0s 33ms/step
# epoch:3928 d_loss:0.4732 g_loss:1.4303
# 1/1 [==============================] - 0s 33ms/step
# epoch:3929 d_loss:0.6222 g_loss:1.6024
# 1/1 [==============================] - 0s 33ms/step
# epoch:3930 d_loss:0.5722 g_loss:1.5376
# 1/1 [==============================] - 0s 34ms/step
# epoch:3931 d_loss:0.4572 g_loss:1.7761
# 1/1 [==============================] - 0s 33ms/step
# epoch:3932 d_loss:0.5591 g_loss:1.6022
# 1/1 [==============================] - 0s 33ms/step
# epoch:3933 d_loss:0.6228 g_loss:1.7531
# 1/1 [==============================] - 0s 32ms/step
# epoch:3934 d_loss:0.3594 g_loss:1.9513
# 1/1 [==============================] - 0s 33ms/step
# epoch:3935 d_loss:0.4944 g_loss:1.4591
# 1/1 [==============================] - 0s 33ms/step
# epoch:3936 d_loss:0.5860 g_loss:1.5226
# 1/1 [==============================] - 0s 33ms/step
# epoch:3937 d_loss:0.4272 g_loss:1.8311
# 1/1 [==============================] - 0s 34ms/step
# epoch:3938 d_loss:0.4175 g_loss:2.0437
# 1/1 [==============================] - 0s 33ms/step
# epoch:3939 d_loss:0.4847 g_loss:2.3443
# 1/1 [==============================] - 0s 33ms/step
# epoch:3940 d_loss:0.3345 g_loss:2.1385
# 1/1 [==============================] - 0s 33ms/step
# epoch:3941 d_loss:0.4532 g_loss:2.2708
# 1/1 [==============================] - 0s 34ms/step
# epoch:3942 d_loss:0.3827 g_loss:1.6282
# 1/1 [==============================] - 0s 33ms/step
# epoch:3943 d_loss:0.3528 g_loss:2.1775
# 1/1 [==============================] - 0s 34ms/step
# epoch:3944 d_loss:0.4020 g_loss:2.2650
# 1/1 [==============================] - 0s 32ms/step
# epoch:3945 d_loss:0.4328 g_loss:2.1015
# 1/1 [==============================] - 0s 33ms/step
# epoch:3946 d_loss:0.4956 g_loss:2.0393
# 1/1 [==============================] - 0s 32ms/step
# epoch:3947 d_loss:0.3209 g_loss:2.4505
# 1/1 [==============================] - 0s 33ms/step
# epoch:3948 d_loss:0.5397 g_loss:2.2434
# 1/1 [==============================] - 0s 33ms/step
# epoch:3949 d_loss:0.5842 g_loss:1.8858
# 1/1 [==============================] - 0s 33ms/step
# epoch:3950 d_loss:0.4691 g_loss:1.9372
# 1/1 [==============================] - 0s 35ms/step
# epoch:3951 d_loss:0.5868 g_loss:1.7031
# 1/1 [==============================] - 0s 33ms/step
# epoch:3952 d_loss:0.5234 g_loss:1.8163
# 1/1 [==============================] - 0s 33ms/step
# epoch:3953 d_loss:0.3870 g_loss:1.6827
# 1/1 [==============================] - 0s 33ms/step
# epoch:3954 d_loss:0.6806 g_loss:1.4327
# 1/1 [==============================] - 0s 33ms/step
# epoch:3955 d_loss:0.6553 g_loss:1.7195
# 1/1 [==============================] - 0s 32ms/step
# epoch:3956 d_loss:0.5397 g_loss:1.6765
# 1/1 [==============================] - 0s 33ms/step
# epoch:3957 d_loss:0.4824 g_loss:2.1135
# 1/1 [==============================] - 0s 33ms/step
# epoch:3958 d_loss:0.5409 g_loss:1.9882
# 1/1 [==============================] - 0s 33ms/step
# epoch:3959 d_loss:0.4367 g_loss:1.4661
# 1/1 [==============================] - 0s 32ms/step
# epoch:3960 d_loss:0.6427 g_loss:1.5716
# 1/1 [==============================] - 0s 33ms/step
# epoch:3961 d_loss:0.4532 g_loss:1.4929
# 1/1 [==============================] - 0s 32ms/step
# epoch:3962 d_loss:0.6078 g_loss:1.4009
# 1/1 [==============================] - 0s 33ms/step
# epoch:3963 d_loss:0.6236 g_loss:1.7768
# 1/1 [==============================] - 0s 33ms/step
# epoch:3964 d_loss:0.6567 g_loss:1.6875
# 1/1 [==============================] - 0s 34ms/step
# epoch:3965 d_loss:0.6807 g_loss:1.4266
# 1/1 [==============================] - 0s 33ms/step
# epoch:3966 d_loss:0.4673 g_loss:1.5181
# 1/1 [==============================] - 0s 33ms/step
# epoch:3967 d_loss:0.5725 g_loss:1.5513
# 1/1 [==============================] - 0s 33ms/step
# epoch:3968 d_loss:0.4575 g_loss:1.4841
# 1/1 [==============================] - 0s 33ms/step
# epoch:3969 d_loss:0.4079 g_loss:1.0885
# 1/1 [==============================] - 0s 33ms/step
# epoch:3970 d_loss:0.4029 g_loss:1.3993
# 1/1 [==============================] - 0s 32ms/step
# epoch:3971 d_loss:0.3334 g_loss:1.5466
# 1/1 [==============================] - 0s 34ms/step
# epoch:3972 d_loss:0.4315 g_loss:2.0025
# 1/1 [==============================] - 0s 33ms/step
# epoch:3973 d_loss:0.3831 g_loss:1.7745
# 1/1 [==============================] - 0s 33ms/step
# epoch:3974 d_loss:0.3562 g_loss:1.6221
# 1/1 [==============================] - 0s 33ms/step
# epoch:3975 d_loss:0.4322 g_loss:1.8282
# 1/1 [==============================] - 0s 34ms/step
# epoch:3976 d_loss:0.4875 g_loss:1.4820
# 1/1 [==============================] - 0s 34ms/step
# epoch:3977 d_loss:0.4614 g_loss:1.6597
# 1/1 [==============================] - 0s 33ms/step
# epoch:3978 d_loss:0.3514 g_loss:1.8243
# 1/1 [==============================] - 0s 33ms/step
# epoch:3979 d_loss:0.3011 g_loss:2.0951
# 1/1 [==============================] - 0s 32ms/step
# epoch:3980 d_loss:0.2961 g_loss:2.5155
# 1/1 [==============================] - 0s 33ms/step
# epoch:3981 d_loss:0.4434 g_loss:2.3935
# 1/1 [==============================] - 0s 33ms/step
# epoch:3982 d_loss:0.5506 g_loss:2.0006
# 1/1 [==============================] - 0s 33ms/step
# epoch:3983 d_loss:0.4747 g_loss:1.6119
# 1/1 [==============================] - 0s 32ms/step
# epoch:3984 d_loss:0.4336 g_loss:1.6156
# 1/1 [==============================] - 0s 34ms/step
# epoch:3985 d_loss:0.6530 g_loss:1.3065
# 1/1 [==============================] - 0s 33ms/step
# epoch:3986 d_loss:0.4422 g_loss:1.6628
# 1/1 [==============================] - 0s 34ms/step
# epoch:3987 d_loss:0.3940 g_loss:1.9615
# 1/1 [==============================] - 0s 33ms/step
# epoch:3988 d_loss:0.3982 g_loss:1.5127
# 1/1 [==============================] - 0s 33ms/step
# epoch:3989 d_loss:0.4169 g_loss:2.1329
# 1/1 [==============================] - 0s 32ms/step
# epoch:3990 d_loss:0.4121 g_loss:1.6283
# 1/1 [==============================] - 0s 33ms/step
# epoch:3991 d_loss:0.4005 g_loss:1.9473
# 1/1 [==============================] - 0s 32ms/step
# epoch:3992 d_loss:0.4831 g_loss:1.3968
# 1/1 [==============================] - 0s 33ms/step
# epoch:3993 d_loss:0.5221 g_loss:1.6319
# 1/1 [==============================] - 0s 33ms/step
# epoch:3994 d_loss:0.7301 g_loss:1.6354
# 1/1 [==============================] - 0s 34ms/step
# epoch:3995 d_loss:0.5298 g_loss:1.4122
# 1/1 [==============================] - 0s 33ms/step
# epoch:3996 d_loss:0.5744 g_loss:1.3803
# 1/1 [==============================] - 0s 34ms/step
# epoch:3997 d_loss:0.5298 g_loss:1.6849
# 1/1 [==============================] - 0s 34ms/step
# epoch:3998 d_loss:0.6012 g_loss:1.3145
# 1/1 [==============================] - 0s 34ms/step
# epoch:3999 d_loss:0.5291 g_loss:1.3856
# 1/1 [==============================] - 0s 32ms/step
# epoch:4000 d_loss:0.4457 g_loss:1.6601
# 1/1 [==============================] - 0s 32ms/step
# /tmp/ipykernel_129241/911656145.py:27: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axs = plt.subplots(5, 5)

# %%
import matplotlib.pyplot as plt
import numpy as np

# X_train 데이터에서 무작위로 32개 이미지를 선택합니다.
random_indices = np.random.randint(0, X_train.shape[0], 32)

# 선택한 이미지를 그립니다.
plt.figure(figsize=(8, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(4, 8, i + 1)
    plt.imshow(X_train[idx].reshape(28, 28), cmap='gray')
    plt.axis('off')

plt.show()

# %% [markdown]
# 결과적으로

# %%
from IPython.display import Image, display
display(Image(filename='gan_images/gan_mnist_4000.png'))

# %% [markdown]
# ### 구분할 수 없는 이미지 만들었다는데 아직 보완이 필요해 보입니다.
# - 사람이 보았을 때 누가봐도 컴퓨터가 만든거잖아!
